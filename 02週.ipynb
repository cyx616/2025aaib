# %%
#week02-1.py F020
a = input("請輸入1個數:")
a=int(a)

if a%2==1: print("odd")
else: print("even")
# Out:
# 請輸入1個數:6
# even

# %% [markdown]
# _+文字，會跳出文字視窗。把剛剛的codeBlocks的截圖Ctrl-V
# ![image.png](data:image/png;base64,...)

# %%
# week02-2.py
a=123
b=100
print("a是","b是",b)
print("整數除法a//b得到",a//b)
print("餘數a%b得到",a%b)
# Out:
# a是 b是 100
# 整數除法a//b得到 1
# 餘數a%b得到 23

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 會很亂,在+程式碼
